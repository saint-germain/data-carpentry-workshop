# %%
import numpy as np
import pandas as pd

# %%
df1=pd.read_csv("hurto-personas-2018_primera_parte.csv",skiprows=8)

# %%
df1.head()
# Out:
#     Fecha Departamento     Municipio    Día      Hora          Barrio    Zona  \
# 0  1/1/18     AMAZONAS  LETICIA (CT)  Lunes   1:30:00        CASTAÑAL  URBANA
# 1  1/1/18    ANTIOQUIA      APARTADÓ  Lunes  10:00:00          CENTRO  URBANA
# 2  1/1/18    ANTIOQUIA      APARTADÓ  Lunes   7:00:00      MANZANAREZ  URBANA
# 3  1/1/18    ANTIOQUIA         BELLO  Lunes  17:00:00  NIQUIA CAMACOL  URBANA
# 4  1/1/18    ANTIOQUIA         BELLO  Lunes   6:00:00    PANAMERICANO  URBANA
#
#                        Clase de sitio        Arma empleada   Móvil Agresor  \
# 0  FRENTE A RESIDENCIAS - VIA PUBLICA  SIN EMPLEO DE ARMAS           A PIE
# 1                   CAJERO AUTOMATICO  SIN EMPLEO DE ARMAS           A PIE
# 2                 CASAS DE HABITACION  SIN EMPLEO DE ARMAS           A PIE
# 3                  ESTACION DEL METRO  SIN EMPLEO DE ARMAS  PASAJERO METRO
# 4             FRENTE CENTRO COMERCIAL        ARMA DE FUEGO           A PIE
#
# ...

# %%
df1.tail(5)
# Out:
#                                                     Fecha Departamento  \
# 121630                                            6/30/18        VALLE
# 121631                                            6/30/18        VALLE
# 121632  FUENTE:   DIJIN-POLICÍA NACIONAL. DATOS EXTRAI...          NaN
# 121633                  Elaboró: PT Andres Felipe Taborda          NaN
# 121634          Revisó: IT. John Alexander Ruíz Rodríguez          NaN
#
#        Municipio     Día      Hora               Barrio    Zona  \
# 121630   PALMIRA  Sábado   7:00:00             ZAMORANO  URBANA
# 121631     YUMBO  Sábado  23:00:00  CGTO SAN MARCOS E25   RURAL
# 121632       NaN     NaN       NaN                  NaN     NaN
# 121633       NaN     NaN       NaN                  NaN     NaN
# 121634       NaN     NaN       NaN                  NaN     NaN
#
#        Clase de sitio                Arma empleada Móvil Agresor  \
# 121630           OTRO  ARMA BLANCA / CORTOPUNZANTE         A PIE
# ...

# %%
df1.drop(df1.tail(3).index,inplace=True)

# %%
df1.tail()
# Out:
#           Fecha Departamento            Municipio     Día      Hora  \
# 121627  6/30/18        VALLE  GUADALAJARA DE BUGA  Sábado  18:00:00
# 121628  6/30/18        VALLE              JAMUNDÍ  Sábado   3:30:00
# 121629  6/30/18        VALLE              PALMIRA  Sábado  19:30:00
# 121630  6/30/18        VALLE              PALMIRA  Sábado   7:00:00
# 121631  6/30/18        VALLE                YUMBO  Sábado  23:00:00
#
#                      Barrio    Zona                  Clase de sitio  \
# 121627     JOSE MARIA CABAL  URBANA  FRENTE A COLEGIO - VIA PUBLICA
# 121628        EL DORADO E24  URBANA                   VIAS PUBLICAS
# 121629  CGTO BOLO LA ITALIA   RURAL                   VIAS PUBLICAS
# 121630             ZAMORANO  URBANA                            OTRO
# 121631  CGTO SAN MARCOS E25   RURAL                   VIAS PUBLICAS
#
#                       Arma empleada         Móvil Agresor Móvil Victima Edad  \
# ...

# %%
df2=pd.read_csv("hurto-personas-2018_segunda_parte.csv",skiprows=8)
# Out:
# /Users/germanchaparro/miniconda2/envs/py36/lib/python3.5/site-packages/IPython/core/interactiveshell.py:2683: DtypeWarning: Columns (18,19) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df2.head()
# Out:
#     Fecha Departamento     Municipio      Día      Hora               Barrio  \
# 0  7/1/18     AMAZONAS  LETICIA (CT)  Domingo  20:00:00          PUNTA BRAVA
# 1  7/1/18    ANTIOQUIA       BARBOSA  Domingo  15:00:00        VDA. LA PLAYA
# 2  7/1/18    ANTIOQUIA       BARBOSA  Domingo   2:30:00          LOS BUCAROS
# 3  7/1/18    ANTIOQUIA         BELLO  Domingo  20:00:00  CIUDADELA DEL NORTE
# 4  7/1/18    ANTIOQUIA         BELLO  Domingo   3:00:00                PRADO
#
#      Zona         Clase de sitio                Arma empleada Móvil Agresor  \
# 0  URBANA          VIAS PUBLICAS          SIN EMPLEO DE ARMAS         A PIE
# 1   RURAL       CENTRO TURÍSTICO  ARMA BLANCA / CORTOPUNZANTE         A PIE
# 2   RURAL               QUEBRADA  ARMA BLANCA / CORTOPUNZANTE         A PIE
# 3  URBANA  ESCENARIOS DEPORTIVOS          SIN EMPLEO DE ARMAS         A PIE
# 4  URBANA          VIAS PUBLICAS                 CONTUNDENTES         A PIE
#
# ...

# %%
df2.tail()
# Out:
#                                                     Fecha Departamento  \
# 133392                                           12/31/18        VALLE
# 133393                                                NaN          NaN
# 133394  FUENTE:   DIJIN-POLICÍA NACIONAL. DATOS EXTRAI...          NaN
# 133395                  Elaboró: PT Andres Felipe Taborda          NaN
# 133396          Revisó: IT. John Alexander Ruíz Rodríguez          NaN
#
#        Municipio    Día      Hora  Barrio    Zona Clase de sitio  \
# 133392   PALMIRA  Lunes  21:15:00  RECREO  URBANA  VIAS PUBLICAS
# 133393       NaN    NaN       NaN     NaN     NaN            NaN
# 133394       NaN    NaN       NaN     NaN     NaN            NaN
# 133395       NaN    NaN       NaN     NaN     NaN            NaN
# 133396       NaN    NaN       NaN     NaN     NaN            NaN
#
#         Arma empleada Móvil Agresor Móvil Victima Edad       Sexo  \
# 133392  ARMA DE FUEGO         A PIE         A PIE   61  MASCULINO
# ...

# %%
df2.drop(df2.tail(4).index,inplace=True)

# %%
df2.tail()
# Out:
#            Fecha Departamento   Municipio    Día      Hora  \
# 133388  12/31/18        VALLE  CANDELARIA  Lunes  22:00:00
# 133389  12/31/18        VALLE     CARTAGO  Lunes  17:30:00
# 133390  12/31/18        VALLE     PALMIRA  Lunes   0:00:00
# 133391  12/31/18        VALLE     PALMIRA  Lunes   4:30:00
# 133392  12/31/18        VALLE     PALMIRA  Lunes  21:15:00
#
#                          Barrio    Zona                      Clase de sitio  \
# 133388            OBRERO (23-2)  URBANA               DENTRO DE LA VIVIENDA
# 133389                   CENTRO  URBANA         ESTABLECIMIENTO DE COMERCIO
# 133390  URB. POBLADO CAMFAUNION  URBANA  FRENTE A RESIDENCIAS - VIA PUBLICA
# 133391                   BERLIN  URBANA                       VIAS PUBLICAS
# 133392                   RECREO  URBANA                       VIAS PUBLICAS
#
#               Arma empleada          Móvil Agresor         Móvil Victima Edad  \
# ...

# %%
df=pd.concat([df1,df2],ignore_index=True)

# %%
np.unique(df.Departamento)
# Out:
# array(['-', 'AMAZONAS', 'ANTIOQUIA', 'ARAUCA', 'ATLÁNTICO', 'BOLÍVAR',
#        'BOYACÁ', 'CALDAS', 'CAQUETÁ', 'CASANARE', 'CAUCA', 'CESAR',
#        'CHOCÓ', 'CUNDINAMARCA', 'CÓRDOBA', 'GUAINÍA', 'GUAJIRA',
#        'GUAVIARE', 'HUILA', 'MAGDALENA', 'META', 'NARIÑO',
#        'NORTE DE SANTANDER', 'PUTUMAYO', 'QUINDÍO', 'RISARALDA',
#        'SAN ANDRÉS', 'SANTANDER', 'SUCRE', 'TOLIMA', 'VALLE', 'VAUPÉS',
#        'VICHADA'], dtype=object)

# %%
np.unique(df.Municipio[df.Departamento=='CUNDINAMARCA'])
# Out:
# array(['AGUA DE DIOS', 'ALBÁN', 'ANAPOIMA', 'ANOLAIMA', 'APULO',
#        'ARBELÁEZ', 'BITUIMA', 'BOGOTÁ D.C. (CT)', 'BOJACÁ', 'CABRERA',
#        'CACHIPAY', 'CAJICÁ', 'CAPARRAPÍ', 'CAQUEZA', 'CARMEN DE CARUPA',
#        'CHIPAQUE', 'CHOACHÍ', 'CHOCONTÁ', 'CHÍA', 'COGUA', 'COTA',
#        'CUCUNUBÁ', 'EL COLEGIO', 'EL PEÑÓN', 'EL ROSAL', 'FACATATIVÁ',
#        'FOMEQUE', 'FOSCA', 'FUNZA', 'FUSAGASUGÁ', 'FÚQUENE', 'GACHALA',
#        'GACHANCIPÁ', 'GACHETÁ', 'GIRARDOT', 'GRANADA', 'GUACHETÁ',
#        'GUADUAS', 'GUASCA', 'GUATAQUÍ', 'GUATAVITA', 'GUAYABAL DE SIQUIMA',
#        'GUAYABETAL', 'GUTIÉRREZ', 'JERUSALÉN', 'JUNÍN', 'LA CALERA',
#        'LA MESA', 'LA PALMA', 'LA PEÑA', 'LA VEGA', 'LENGUAZAQUE',
#        'MACHETA', 'MADRID', 'MANTA', 'MEDINA', 'MOSQUERA', 'NARIÑO',
#        'NEMOCÓN', 'NILO', 'NIMAIMA', 'NOCAIMA', 'PACHO', 'PAIME', 'PANDI',
#        'PARATEBUENO', 'PASCA', 'PUERTO SALGAR', 'QUEBRADANEGRA', 'QUETAME',
# ...

# %%
dfout=df[df.Municipio=='BOGOTÁ D.C. (CT)']

# %%
dfout.head()
# Out:
#       Fecha  Departamento         Municipio    Día     Hora  \
# 117  1/1/18  CUNDINAMARCA  BOGOTÁ D.C. (CT)  Lunes  0:00:00
# 118  1/1/18  CUNDINAMARCA  BOGOTÁ D.C. (CT)  Lunes  0:00:00
# 119  1/1/18  CUNDINAMARCA  BOGOTÁ D.C. (CT)  Lunes  0:00:00
# 120  1/1/18  CUNDINAMARCA  BOGOTÁ D.C. (CT)  Lunes  0:00:00
# 121  1/1/18  CUNDINAMARCA  BOGOTÁ D.C. (CT)  Lunes  0:00:00
#
#                      Barrio    Zona       Clase de sitio  \
# 117            BOLIVIA E-10  URBANA        VIAS PUBLICAS
# 118  CIUDAD SALITRE II E-13  URBANA        VIAS PUBLICAS
# 119   ESTACIÓN CENTRAL E-16  URBANA  CASAS DE HABITACION
# 120          LA CABRERA E-2  URBANA        VIAS PUBLICAS
# 121           LA CHUCUA E-8  URBANA        VIAS PUBLICAS
#
#                    Arma empleada Móvil Agresor Móvil Victima Edad       Sexo  \
# 117  ARMA BLANCA / CORTOPUNZANTE         A PIE         A PIE   18  MASCULINO
# 118                 CONTUNDENTES         A PIE         A PIE   61   FEMENINO
# ...

# %%
dfout.to_csv('robo-personas-bogota-2018.csv')
